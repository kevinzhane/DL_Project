# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import *
from keras.callbacks import *
from sklearn.preprocessing import *
from keras.preprocessing import *

data_1=pd.read_csv('cocktails.csv')
#X_train=data_1.drop(['Bartender','Bar/Company','Location','Garnish','Glassware','Preparation','Notes'],axis=1).values
#Y_train=data_1['Cocktail Name'].values

X_train=data_1['Ingredients'].values
#Y_train=[1:655]
#print(X_train)

X_test=data_1['Ingredients'][0]
#print(X_test)


Y=pd.get_dummies(data_1['Cocktail Name'])
#print(Y.head(1))

Y1_train = {}


for i in data_1['Cocktail Name']:
    Y1_train[i]=i

# %%
from keras.preprocessing.text import Tokenizer

token = Tokenizer(num_words=20000)
token.fit_on_texts(X_train)
#token.fit_on_texts(Y_train)

#print(token.word_index)
#print(X_train)
X1_train = token.texts_to_sequences(X_train)
#Y1_train = token.texts_to_sequences(Y_train)

X1_test = token.texts_to_sequences(X_test)

max_seq_len = max([
    len(seq) for seq in X1_train])
print(max_seq_len)

max_seq_len0 = max([
    len(seq) for seq in Y1_train])

X1_train = sequence.pad_sequences(X1_train, max_seq_len)
#Y1_train = sequence.pad_sequences(Y1_train, max_seq_len0)

#print(Y1_train.shape)

X1_test = sequence.pad_sequences(X1_test, max_seq_len)

from keras.layers.core import Dense, Dropout, Activation,Flatten
from keras.layers.embeddings import Embedding

model = Sequential()
model.add(Embedding(input_dim=20000, 
                    output_dim=128,
                    input_length=43))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(units=256,
                activation='relu' ))
model.add(Dropout(0.2))
model.add(Dense(units=684,
                activation='sigmoid' ))
model.summary()

model.compile(loss='binary_crossentropy',metrics=['accuracy'],optimizer='nadam')
#進行訓練
#batch_size：每一批次訓練100筆資料
#epochs：執行10個訓練週期
#verbose：顯示每次的訓練過程
#validation_split：測試資料的比例
his =model.fit(X1_train, Y,batch_size=10,
                         epochs=50,verbose=2,validation_split=0.25)
# Out:
# 43
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 43, 128)           2560000
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 43, 128)           0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 5504)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               1409280
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 684)               175788
# =================================================================
# Total params: 4,145,068
# Trainable params: 4,145,068
# Non-trainable params: 0
# _________________________________________________________________
# /home/kevin-home/.local/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 515 samples, validate on 172 samples
# Epoch 1/50
#  - 1s - loss: 0.0804 - accuracy: 0.9805 - val_loss: 0.0148 - val_accuracy: 0.9985
# Epoch 2/50
#  - 0s - loss: 0.0127 - accuracy: 0.9985 - val_loss: 0.0137 - val_accuracy: 0.9985
# Epoch 3/50
#  - 0s - loss: 0.0118 - accuracy: 0.9985 - val_loss: 0.0139 - val_accuracy: 0.9985
# Epoch 4/50
#  - 0s - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0138 - val_accuracy: 0.9985
# Epoch 5/50
#  - 0s - loss: 0.0112 - accuracy: 0.9985 - val_loss: 0.0141 - val_accuracy: 0.9985
# Epoch 6/50
#  - 0s - loss: 0.0108 - accuracy: 0.9985 - val_loss: 0.0147 - val_accuracy: 0.9985
# Epoch 7/50
#  - 1s - loss: 0.0101 - accuracy: 0.9985 - val_loss: 0.0150 - val_accuracy: 0.9985
# Epoch 8/50
#  - 0s - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.0151 - val_accuracy: 0.9985
# Epoch 9/50
#  - 0s - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.0170 - val_accuracy: 0.9985
# Epoch 10/50
#  - 0s - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.0164 - val_accuracy: 0.9985
# Epoch 11/50
#  - 0s - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0176 - val_accuracy: 0.9985
# Epoch 12/50
#  - 1s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0179 - val_accuracy: 0.9985
# Epoch 13/50
#  - 0s - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0195 - val_accuracy: 0.9985
# Epoch 14/50
#  - 0s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0215 - val_accuracy: 0.9985
# Epoch 15/50
#  - 1s - loss: 9.3114e-04 - accuracy: 0.9997 - val_loss: 0.0230 - val_accuracy: 0.9985
# Epoch 16/50
#  - 0s - loss: 6.2511e-04 - accuracy: 0.9999 - val_loss: 0.0236 - val_accuracy: 0.9985
# Epoch 17/50
#  - 0s - loss: 4.9041e-04 - accuracy: 0.9999 - val_loss: 0.0249 - val_accuracy: 0.9985
# Epoch 18/50
#  - 0s - loss: 3.9899e-04 - accuracy: 0.9999 - val_loss: 0.0252 - val_accuracy: 0.9985
# Epoch 19/50
#  - 0s - loss: 3.2714e-04 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9985
# Epoch 20/50
#  - 0s - loss: 2.5187e-04 - accuracy: 1.0000 - val_loss: 0.0262 - val_accuracy: 0.9985
# Epoch 21/50
#  - 0s - loss: 2.3162e-04 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9985
# Epoch 22/50
#  - 1s - loss: 2.1574e-04 - accuracy: 0.9999 - val_loss: 0.0270 - val_accuracy: 0.9985
# Epoch 23/50
#  - 0s - loss: 1.6022e-04 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 0.9985
# Epoch 24/50
#  - 0s - loss: 1.4697e-04 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9985
# Epoch 25/50
#  - 0s - loss: 1.6876e-04 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9985
# Epoch 26/50
#  - 0s - loss: 1.3434e-04 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9985
# Epoch 27/50
#  - 0s - loss: 1.2417e-04 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 0.9985
# Epoch 28/50
#  - 0s - loss: 8.9821e-05 - accuracy: 1.0000 - val_loss: 0.0288 - val_accuracy: 0.9985
# Epoch 29/50
#  - 0s - loss: 9.7188e-05 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9985
# Epoch 30/50
#  - 0s - loss: 9.3191e-05 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9985
# Epoch 31/50
#  - 0s - loss: 9.7067e-05 - accuracy: 1.0000 - val_loss: 0.0296 - val_accuracy: 0.9985
# Epoch 32/50
#  - 0s - loss: 1.0963e-04 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9985
# Epoch 33/50
#  - 0s - loss: 8.8684e-05 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9985
# Epoch 34/50
#  - 0s - loss: 7.3487e-05 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9985
# Epoch 35/50
#  - 0s - loss: 7.4091e-05 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9985
# Epoch 36/50
#  - 0s - loss: 6.0676e-05 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 0.9985
# Epoch 37/50
#  - 0s - loss: 6.3228e-05 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9985
# Epoch 38/50
#  - 0s - loss: 5.9700e-05 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9985
# Epoch 39/50
#  - 0s - loss: 6.7832e-05 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9985
# Epoch 40/50
#  - 0s - loss: 5.5773e-05 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9985
# Epoch 41/50
#  - 0s - loss: 5.5874e-05 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9985
# Epoch 42/50
#  - 0s - loss: 6.4309e-05 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9985
# Epoch 43/50
#  - 0s - loss: 4.2016e-05 - accuracy: 1.0000 - val_loss: 0.0295 - val_accuracy: 0.9985
# Epoch 44/50
#  - 0s - loss: 5.2776e-05 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 0.9985
# Epoch 45/50
#  - 0s - loss: 7.5155e-05 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9985
# Epoch 46/50
#  - 0s - loss: 5.9675e-05 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9985
# Epoch 47/50
#  - 0s - loss: 6.4687e-05 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 0.9985
# Epoch 48/50
#  - 0s - loss: 5.7247e-05 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9985
# Epoch 49/50
#  - 0s - loss: 5.8934e-05 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9985
# Epoch 50/50
#  - 0s - loss: 5.2750e-05 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9985

# %%
import matplotlib.pyplot as plt

plt.plot(his.history['loss'])       
plt.plot(his.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Validation Mae')

#plt.savefig(fn)  

plt.show()
  
pred =model.predict(X1_test)
print(pred)

"""                    
#評估訓練模型的準確率
acu = model.evaluate(x_test, y_test, verbose=1)
acu[1]
"""
"""
index_to_label = {v: k for k, v in Y.items()}

test['Category'] = [index_to_label[idx] for idx in np.argmax(pred, axis=1)]

submission = test.loc[:, ['Category']].reset_index()

submission.columns = ['Id', 'Category']
"""
