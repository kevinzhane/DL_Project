# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import *
from keras.callbacks import *
from sklearn.preprocessing import *
from keras.preprocessing import *

data_1=pd.read_csv('cocktails.csv')
#X_train=data_1.drop(['Bartender','Bar/Company','Location','Garnish','Glassware','Preparation','Notes'],axis=1).values
#Y_train=data_1['Cocktail Name'].values

X_train=data_1['Ingredients'].values
#Y_train=[1:655]
#print(X_train)

X_test=data_1['Ingredients'][0]
#print(X_test)


Y=pd.get_dummies(data_1['Cocktail Name'])
#print(Y.head(1))

Y1_train = {}


for i in data_1['Cocktail Name']:
    Y1_train[i]=i

# %%
from keras.preprocessing.text import Tokenizer

token = Tokenizer(num_words=20000)
token.fit_on_texts(X_train)
#token.fit_on_texts(Y_train)

#print(token.word_index)
#print(X_train)
X1_train = token.texts_to_sequences(X_train)
#Y1_train = token.texts_to_sequences(Y_train)

X1_test = token.texts_to_sequences(X_test)

max_seq_len = max([
    len(seq) for seq in X1_train])
print(max_seq_len)

max_seq_len0 = max([
    len(seq) for seq in Y1_train])

X1_train = sequence.pad_sequences(X1_train, max_seq_len)
#Y1_train = sequence.pad_sequences(Y1_train, max_seq_len0)

#print(Y1_train.shape)

X1_test = sequence.pad_sequences(X1_test, max_seq_len)

from keras.layers.core import Dense, Dropout, Activation,Flatten
from keras.layers.embeddings import Embedding

model = Sequential()
model.add(Embedding(input_dim=20000, 
                    output_dim=128,
                    input_length=43))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(units=256,
                activation='relu' ))
model.add(Dropout(0.2))
model.add(Dense(units=684,
                activation='sigmoid' ))
model.summary()

model.compile(loss='binary_crossentropy',metrics=['accuracy'],optimizer='nadam')
#進行訓練
#batch_size：每一批次訓練100筆資料
#epochs：執行10個訓練週期
#verbose：顯示每次的訓練過程
#validation_split：測試資料的比例
his =model.fit(X1_train, Y,batch_size=10,
                         epochs=50,verbose=2,validation_split=0.25)
# Out:
# 43
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 43, 128)           2560000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 43, 128)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 5504)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               1409280
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 684)               175788
# =================================================================
# Total params: 4,145,068
# Trainable params: 4,145,068
# Non-trainable params: 0
# _________________________________________________________________
# /home/kevin-home/.local/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 515 samples, validate on 172 samples
# Epoch 1/50
#  - 0s - loss: 0.5480 - accuracy: 0.8301 - val_loss: 0.1286 - val_accuracy: 0.9985
# Epoch 2/50
#  - 0s - loss: 0.0627 - accuracy: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9985
# Epoch 3/50
#  - 0s - loss: 0.0135 - accuracy: 0.9985 - val_loss: 0.0135 - val_accuracy: 0.9985
# Epoch 4/50
#  - 0s - loss: 0.0133 - accuracy: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9985
# Epoch 5/50
#  - 0s - loss: 0.0140 - accuracy: 0.9985 - val_loss: 0.0154 - val_accuracy: 0.9985
# Epoch 6/50
#  - 0s - loss: 0.0137 - accuracy: 0.9985 - val_loss: 0.0153 - val_accuracy: 0.9985
# Epoch 7/50
#  - 0s - loss: 0.0130 - accuracy: 0.9985 - val_loss: 0.0150 - val_accuracy: 0.9985
# Epoch 8/50
#  - 0s - loss: 0.0123 - accuracy: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9985
# Epoch 9/50
#  - 0s - loss: 0.0118 - accuracy: 0.9985 - val_loss: 0.0147 - val_accuracy: 0.9985
# Epoch 10/50
#  - 0s - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9985
# Epoch 11/50
#  - 0s - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9985
# Epoch 12/50
#  - 0s - loss: 0.0111 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9985
# Epoch 13/50
#  - 0s - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.0145 - val_accuracy: 0.9985
# Epoch 14/50
#  - 0s - loss: 0.0109 - accuracy: 0.9985 - val_loss: 0.0145 - val_accuracy: 0.9985
# Epoch 15/50
#  - 0s - loss: 0.0107 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9985
# Epoch 16/50
#  - 0s - loss: 0.0107 - accuracy: 0.9985 - val_loss: 0.0146 - val_accuracy: 0.9985
# Epoch 17/50
#  - 0s - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.0147 - val_accuracy: 0.9985
# Epoch 18/50
#  - 0s - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9985
# Epoch 19/50
#  - 0s - loss: 0.0105 - accuracy: 0.9985 - val_loss: 0.0148 - val_accuracy: 0.9985
# Epoch 20/50
#  - 0s - loss: 0.0104 - accuracy: 0.9985 - val_loss: 0.0149 - val_accuracy: 0.9985
# Epoch 21/50
#  - 0s - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.0150 - val_accuracy: 0.9985
# Epoch 22/50
#  - 0s - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.0151 - val_accuracy: 0.9985
# Epoch 23/50
#  - 0s - loss: 0.0101 - accuracy: 0.9985 - val_loss: 0.0152 - val_accuracy: 0.9985
# Epoch 24/50
#  - 0s - loss: 0.0100 - accuracy: 0.9985 - val_loss: 0.0152 - val_accuracy: 0.9985
# Epoch 25/50
#  - 0s - loss: 0.0099 - accuracy: 0.9985 - val_loss: 0.0152 - val_accuracy: 0.9985
# Epoch 26/50
#  - 0s - loss: 0.0098 - accuracy: 0.9985 - val_loss: 0.0153 - val_accuracy: 0.9985
# Epoch 27/50
#  - 0s - loss: 0.0097 - accuracy: 0.9985 - val_loss: 0.0153 - val_accuracy: 0.9985
# Epoch 28/50
#  - 0s - loss: 0.0095 - accuracy: 0.9985 - val_loss: 0.0155 - val_accuracy: 0.9985
# Epoch 29/50
#  - 0s - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.0154 - val_accuracy: 0.9985
# Epoch 30/50
#  - 0s - loss: 0.0092 - accuracy: 0.9985 - val_loss: 0.0155 - val_accuracy: 0.9985
# Epoch 31/50
#  - 0s - loss: 0.0090 - accuracy: 0.9985 - val_loss: 0.0156 - val_accuracy: 0.9985
# Epoch 32/50
#  - 0s - loss: 0.0088 - accuracy: 0.9985 - val_loss: 0.0157 - val_accuracy: 0.9985
# Epoch 33/50
#  - 0s - loss: 0.0086 - accuracy: 0.9985 - val_loss: 0.0157 - val_accuracy: 0.9985
# Epoch 34/50
#  - 0s - loss: 0.0084 - accuracy: 0.9985 - val_loss: 0.0159 - val_accuracy: 0.9985
# Epoch 35/50
#  - 0s - loss: 0.0081 - accuracy: 0.9985 - val_loss: 0.0159 - val_accuracy: 0.9985
# Epoch 36/50
#  - 0s - loss: 0.0077 - accuracy: 0.9985 - val_loss: 0.0161 - val_accuracy: 0.9985
# Epoch 37/50
#  - 0s - loss: 0.0074 - accuracy: 0.9985 - val_loss: 0.0160 - val_accuracy: 0.9985
# Epoch 38/50
#  - 0s - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.0163 - val_accuracy: 0.9985
# Epoch 39/50
#  - 0s - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0162 - val_accuracy: 0.9985
# Epoch 40/50
#  - 0s - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.0166 - val_accuracy: 0.9985
# Epoch 41/50
#  - 0s - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.0167 - val_accuracy: 0.9985
# Epoch 42/50
#  - 0s - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0168 - val_accuracy: 0.9985
# Epoch 43/50
#  - 0s - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0170 - val_accuracy: 0.9985
# Epoch 44/50
#  - 0s - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0174 - val_accuracy: 0.9985
# Epoch 45/50
#  - 0s - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0177 - val_accuracy: 0.9985
# Epoch 46/50
#  - 0s - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0177 - val_accuracy: 0.9985
# Epoch 47/50
#  - 0s - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0183 - val_accuracy: 0.9985
# Epoch 48/50
#  - 0s - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0184 - val_accuracy: 0.9985
# Epoch 49/50
#  - 0s - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0188 - val_accuracy: 0.9985
# Epoch 50/50
#  - 0s - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0191 - val_accuracy: 0.9985

# %%
import matplotlib.pyplot as plt

plt.plot(his.history['loss'])       
plt.plot(his.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Validation Mae')

#plt.savefig(fn)  

plt.show()
  
pred =model.predict(X1_test)
print(pred)

"""                    
#評估訓練模型的準確率
acu = model.evaluate(x_test, y_test, verbose=1)
acu[1]
"""
"""
index_to_label = {v: k for k, v in Y.items()}

test['Category'] = [index_to_label[idx] for idx in np.argmax(pred, axis=1)]

submission = test.loc[:, ['Category']].reset_index()

submission.columns = ['Id', 'Category']
"""
